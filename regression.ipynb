# %%
import pandas as pd
import torch

# %%
data = pd.read_csv("C:\\Users\\dllab\\Downloads\\winequality-white.csv")
data = pd.DataFrame(data,columns = ["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"])

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               NaN               NaN          NaN             NaN        NaN
# 2               NaN               NaN          NaN             NaN        NaN
# 3               NaN               NaN          NaN             NaN        NaN
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 4893            NaN               NaN          NaN             NaN        NaN
# 4894            NaN               NaN          NaN             NaN        NaN
# 4895            NaN               NaN          NaN             NaN        NaN
# 4896            NaN               NaN          NaN             NaN        NaN
# 4897            NaN               NaN          NaN             NaN        NaN
#
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X = torch.tensor(data.drop("quality", axis=1).values, dtype=torch.float)
y = torch.tensor(data["quality"].values,dtype=torch.float)
print(X.shape, y.shape)
# Out:
# torch.Size([4898, 11]) torch.Size([4898])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size=0.8, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size=0.8, random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'
